# %% [markdown]
# # Lab1

# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Custom functions

# %%
"""
def grade_setter(x: int) -> str:
    conditions = [ 
        (x > 90),
        (x > 80) and (x <= 90),
        (x > 70) and (x <= 80),
        (x > 60) and (x <= 70),
        (x > 50) and (x <= 60),
        (x <=50)
    ]

    values = ['A', 'B', 'C', 'D', 'E', 'F']
    grades = np.select(conditions, values)
    return grades
"""
# Out:
# "\ndef grade_setter(x: int) -> str:\n    conditions = [ \n        (x > 90),\n        (x > 80) and (x <= 90),\n        (x > 70) and (x <= 80),\n        (x > 60) and (x <= 70),\n        (x > 50) and (x <= 60),\n        (x <=50)\n    ]\n\n    values = ['A', 'B', 'C', 'D', 'E', 'F']\n    grades = np.select(conditions, values)\n    return grades\n"

# %%
def grade_setter(x: int) -> str:
    if x == 0:
        return "Undefined grade"
    if x < 18:
        return "F" 
    if 19 <= x <38:
        return "E"
    if 39 <= x < 58:
        return "D" 
    if 58 <= x < 78:
        return "C" 
    if 78 <= x < 93:
        return "B" 
    if x>=93:
        return "A"

# %% [markdown]
# # Fetching data

# %%
url = 'https://raw.githubusercontent.com/DAVE3625-22H/Lab-1/main/students.csv'
df = pd.read_csv(url)

# %% [markdown]
# # Exploring data

# %%
df
# Out:
#     StudentID  Age              email hrsStudy  FinalGrade
# 0       47412   20  s47412@oslomet.no        5        46.0
# 1       15077   22  s15077@oslomet.no        0        65.0
# 2       15467   27  s15467@oslomet.no        1        26.0
# 3       17907   21  s17907@oslomet.no        6        68.0
# 4       13352  333  s13352@oslomet.no        4        34.0
# 5       88403   29  s88403@oslomet.no       11        62.0
# 6       56387   32  s56387@oslomet.no        9        29.0
# 7       95648   23  s95648@oslomet.no        3        38.0
# 8       63176   20  s63176@oslomet.no        0        98.0
# 9       15406   31  s15406@oslomet.no        2        68.0
# 10      41908   24  s41908@oslomet.no        0        62.0
# 11      35600   30  s35600@oslomet.no       11        70.0
# 12      16171   25  s16171@oslomet.no       10        81.0
# 13      55586   24  s55586@oslomet.no        7        31.0
# 14      71505   23  s71505@oslomet.no        1        49.0
# ...

# %% [markdown]
# # Data Cleaning

# %%
# Replaces all places where NaN=True.
df=df.replace(r'^\s*$', np.nan, regex=True)

# Drops NaN-values.
df.dropna(inplace=True)
df.isna().sum()
# Out:
# StudentID     0
# Age           0
# email         0
# hrsStudy      0
# FinalGrade    0
# dtype: int64

# %%
# Could also change NaN to zero-value, and get undefined grade
df = df.fillna(0)

# Checks if there are any columns containing NaN-values.
df.isna().sum()
# Out:
# StudentID     0
# Age           0
# email         0
# hrsStudy      0
# FinalGrade    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   StudentID   48 non-null     int64
#  1   Age         48 non-null     int64
#  2   email       48 non-null     object
#  3   hrsStudy    48 non-null     object
#  4   FinalGrade  48 non-null     float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 2.2+ KB

# %%
# Removing outliers
col = ["FinalGrade"]

q1 = df[col].quantile(0.25)
q3 = df[col].quantile(0.75)
iqr = q3 - q1

df = df[~((df[col] < (q1 - 1.5* iqr)) | (df[col] > (q3 + 1.5*iqr))).any(axis=1)]

# %% [markdown]
# # Feature Engineering - Making letter grade

# %%
# Applying the lambda function on 'Lettergrade'-column
df["LetterGrade"] = df["FinalGrade"].apply(lambda x: grade_setter(x))

# %%
df["LetterGrade"].value_counts()
# Out:
# D    11
# C    11
# E    11
# B     9
# A     4
# Name: LetterGrade, dtype: int64

# %%
# Built in plot to be fancy
df["LetterGrade"].value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:>
